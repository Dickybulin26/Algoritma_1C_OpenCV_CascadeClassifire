# %% [markdown]
# <a href="https://colab.research.google.com/github/Dickybulin26/Algoritma_1C_OpenCV_CascadeClassifire/blob/main/opencv_face_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Program Face Tracking Menggunakan Algoritma Cascade Classifire dari Library OpenCV**

# %% [markdown]
# ## Anggota Kelompok Bubadibako:
#
# - Naufaldy
# - Fadilah
# - Yudha
# - Bunga
# - Fauzan
# - Dicky
# - Nabil

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d2/OpenCV_logo_black.svg/907px-OpenCV_logo_black.svg.png" alt="opencv" width="20%">
# <img src="https://www.mygreatlearning.com/blog/wp-content/uploads/2020/08/dp.png" alt="face tracking" width="30%">
#
# # **Apa itu Face Tracking?**
#
# Face tracking  atau pelacakan wajah adalah teknologi yang dapat mendeteksi dan mengikuti posisi wajah seseorang secara real time melalui kamera.
#
# Teknologi ini banyak digunakan dalam:
#
# - Sistem keamanan otomatis
# - Absensi berbasi wajah
# - Efek kamera
#
# Salah satu cara untuk membuat face tracking adalah dengan algoritma Cascade Classifier dari Library OpenCV di Python.
#
# OpenCV (Open Source Computer Vision Library) adalah library open source untuk pengolahan  gambar atau video, serta pengembangan sistem visi komputer (computer vision) dan pembelajaran mesin (machine learning).

# %% [markdown]
# ### install library opencv

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.13/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in ./.venv/lib/python3.13/site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### import library opencv

# %%
import cv2
import sys

# %% [markdown]
# ### buka kamera perangkat (0 = merupakan kamera default laptop)

# %%
print("🔍 Initializing camera system...")

camera = cv2.VideoCapture(0)

if not camera.isOpened():
    print("""
❌ CRITICAL ERROR: Camera access failed

Possible reasons:
• Camera not connected
• Camera in use by another app
• Wrong camera index
• Driver issues
""")
    sys.exit("Kernel stopped - Fix camera issue and re  start kernel")

print("✅ Camera access confirmed!")
print("📷 Camera ready for computer vision tasks")
# Out:
# 🔍 Initializing camera system...
# ✅ Camera access confirmed!
# 📷 Camera ready for computer vision tasks

# %% [markdown]
# ## **Algoritma Cascade Classifier**

# %% [markdown]
# <center>
# </center>
#
# Casecade Classifier adalah algoritma deteksi objek yang dikembangkan oleh Viola dan Jones pada tahun 2001. Disebut Cascade karena prosesnya bertingkat, mulai dari penyaringan sederhana sampai kompleks.
#
# Algoritma dari cascade classifier berjalan mengunakan library OpenCV yang melalui proses 4 tahap yaitu :
#
# 1. **Selecting Haar-like features :**
#
# <center>
# <img src="https://i.sstatic.net/ssXnC.png" alt="haar-like" width="40%">
# </center>
#
# Merupakan proses memilih pola-pola sederhana (fitur Haar) yang digunakan untuk mengenali ciri khas suatu objek, seperti perbedaan terang dan gelap pada wajah. Fitur ini membantu mendeteksi bagian-bagian penting dari objek, seperti mata, hidung, atau tepi wajah
#
# Tentu. Rumus tersebut adalah inti dari cara kerja Haar-like Features, yang merupakan fondasi dari algoritma deteksi wajah Viola-Jones.
#
# Secara sederhana, rumus ini bekerja dengan membandingkan total kecerahan (intensitas) piksel di area hitam dengan total kecerahan piksel di area putih pada sebuah templat fitur.
#
# #### **Keterangan Algoritma**
#
# Berikut ini adalah keterangan dari setiap komponen pada rumus:
#
# ### **$$f(x, y) = \sum_{i \in R_b} p(i) - \sum_{i \in R_w} p(i)$$**
#
# $$\text{Nilai Fitur} = \text{Jumlah Intensitas Piksel di Area Hitam} - \text{Jumlah Intensitas Piksel di Area Putih}$$
#
# - **$f(x, y)$** : Ini adalah nilai akhir atau skor dari fitur tersebut ketika ditempatkan pada posisi (x, y) di gambar. Hasilnya adalah satu angka tunggal.
#
# - **$\sum$** (Sigma) : Ini adalah simbol matematika untuk iterasi. Artinya summation atau "jumlahkan semua..."
#
# - **$i \in R_b$** : p berarti pixel intensity (nilai kecerahan piksel, biasanya 0 untuk hitam pekat dan 255 untuk putih pekat).
# Subskrip b berarti black (hitam).
# Jadi, Σ **$i \in R_b$**  berarti "total jumlah nilai kecerahan dari semua piksel yang berada di bawah area hitam pada templat."
#
# - **$i \in R_w$**: p berarti pixel intensity.
# Subskrip w berarti white (putih).
# Jadi, Σ **$i \in R_w$** berarti "total jumlah nilai kecerahan dari semua piksel yang berada di bawah area putih pada templat."
#
# - **$p(i)$** Intensitas (nilai kecerahan) piksel pada indeks $i$.
#
# 2. **Creating an integral image :**
#
# Tahap ini membuat representasi gambar baru di mana setiap titik menyimpan jumlah total nilai piksel dari sudut kiri atas hingga titik tersebut. Teknik ini digunakan untuk mempercepat perhitungan fitur Haar di berbagai area gambar.
#
#   <center>
#       <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*H_2BKqQKmrI8uAeY" alt="integral image" width="40%">
#   </center>
#
# Gambar integral memberikan cara cepat dan sederhana untuk menghitung nilai fitur Haar-like feature. Hal ini dilakukan dengan memanfaatkan Summed Area Table. Nilai untuk lokasi (x, y) pada gambar integral adalah jumlah piksel di atas dan di kiri (x, y) pada gambar asli ditambah dirinya sendiri. Misalnya, untuk menghitung (2,2) = 16 = 5+2+3+6
#
# Setelah membangun gambar integral, gambar tersebut digunakan untuk menghitunng diinginkan.
#
#   <center>
#       <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*EJqS55ys5KY8Rfip" alt="integral image2" width="40%">
#   </center>
#
# Untuk mendapatkan jumlah persegi panjang biru, cukup tambahkan nilai hijau dan kurangi nilai merah pada gambar integral. 1+21–11–3 = 8.
#
#   <center>
#       <img src="https://i.sstatic.net/V7x9c.png" alt="integral image after" width="40%">
#   </center>
#
# 3. **Running AdaBoost training :**
# Pada tahap ini, digunakan algoritma pembelajaran AdaBoost untuk memilih dan menggabungkan fitur-fitur terbaik (yang paling mampu membedakan antara objek dan bukan objek) menjadi sebuah model klasifikasi yang kuat. Algoritma ini juga memberi bobot lebih pada kesalahan, agar model terus membaik pada setiap iterasi.
# <center>
#     <img src="https://i.sstatic.net/K1TpT.png" alt="adaboost" width="40%">
# </center>
#
# 4. **Creating classifier cascades :**
# Proses menyusun beberapa classifier secara bertahap, dari yang paling sederhana hingga yang lebih kompleks. Setiap tahap bertugas menyaring area gambar jika sebuah area gagal pada tahap awal, maka langsung dianggap bukan objek dan tidak dilanjutkan ke tahap berikutnya. Pendekatan ini membuat proses deteksi menjadi jauh lebih cepat dan efisien.
# <center>
# <img src="https://www.mygreatlearning.com/blog/wp-content/uploads/2020/08/dp.png" alt="face tracking" width="30%">
# </center>

# %% [markdown]
# ### **Cara Kerja Sederhana Algoritma Cascade Classifier**
#
# - Gambar wajah dibaca frame per frame dari kamera.
# - Algoritma memeriksa tiap bagian gambar menggunakan fitur Haar-Like.
# - Tiap tahap menyaring bagian yang tidak mirip wajah.
# - Bagian yang lolos dari semua tahap dianggap wajah.

# %% [markdown]
# ### **Kenapa Dipakai di OpenCV**
#
# - Cepat, karena tidak perlu memproses seluruh piksel.
# - Sudah tersedia dalam bentuk model XML yang bisa langsung di gunakan, contohnya “haarcascade_frontalfcae_default.xml”.

# %% [markdown]
# # **Kelebihan dan Kekurangan**
#
# ### **Kelebihan:**
#
# - Proses cepat dan ringan untuk real time.
# - Mudah diimplementasikan.
# - Tidak butuh data training tambahan.
#
# ### **Kekurangan:**
# - Kurang akurat pada pencahayan rendah.
# - Tidak bisa mengenali wajah individu (hanya mendeteksi wajah).
# - Sulit mendeteksi wajah dari samping tau miring.

# %% [markdown]
# ### memanggil model Cascade Classifire bawaan dari library opencv untuk face tracking

# %%
face_cascade_model = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# %% [markdown]
# ### melakukan train model dan mendeteksi wajah

# %%
while True:
    # * baca frame dari kamera
    IsSuccess, frame = camera.read()

    # * ubah ke grayscale
    grayScale = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # * deteksi wajah
    faces = face_cascade_model.detectMultiScale(
        image=grayScale,  # * masukan gambar yang sudah di konversi warnanya menjadi abu-abu
        scaleFactor=1.3,  # * mengontrol ukuran gambar yang dikecilkan pada setiap langkah sebesar 30%
        minNeighbors=5 # * menentukan banyak "tetangga" atau deteksi wajah (semakin kecil angkanya maka false positif semakin tinggi)
    )

    print(type(faces))
    print(faces)

    # * gambar kotak di wajah
    for (x, y, w, h) in faces:
        cv2.rectangle(
            img=frame,
            pt1=(x, y),  # * Titik pertama atau sudut kiri atas dari persegi panjang
            pt2=(x+w, y+h), # * Titik kedua atau sudut kanan bawah dari persegi panjang. Koordinatnya didapat dengan menjumlahkan x dengan lebar (w) dan y dengan tinggi (h).
            color=(0, 255, 0),  # * warna kotak hijau (BGR)
            thickness=2  # * ketebalan kotak dalam satuan pixel
        )

    # * tampilkan video
    cv2.imshow("grayScale effect", grayScale)
    cv2.imshow('Face Tracking', frame)

    # * tekan q buat keluar
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# <class 'numpy.ndarray'>
# [[241 200 117 117]]
# <class 'numpy.ndarray'>
# [[240 200 118 118]]
# <class 'numpy.ndarray'>
# [[239 198 120 120]]
# <class 'numpy.ndarray'>
# [[240 198 120 120]]
# <class 'numpy.ndarray'>
# [[239 199 120 120]]
# <class 'numpy.ndarray'>
# [[240 199 120 120]]
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/dicky/Dokumen/CODING/Algoritma_1C_OpenCV_CascadeClassifire/.venv/lib/python3.13/site-packages/cv2/qt/plugins"
# <class 'numpy.ndarray'>
# [[239 198 123 123]]
# <class 'numpy.ndarray'>
# [[240 199 120 120]]
# <class 'numpy.ndarray'>
# [[241 200 118 118]]
# <class 'numpy.ndarray'>
# [[241 200 119 119]]
# <class 'numpy.ndarray'>
# [[241 201 117 117]]
# <class 'numpy.ndarray'>
# [[241 200 119 119]]
# <class 'numpy.ndarray'>
# [[239 199 121 121]]
# <class 'numpy.ndarray'>
# [[240 201 118 118]]
# <class 'numpy.ndarray'>
# [[242 201 118 118]]
# <class 'numpy.ndarray'>
# [[242 202 117 117]]
# <class 'numpy.ndarray'>
# [[240 201 118 118]]
# <class 'numpy.ndarray'>
# [[240 201 119 119]]
# <class 'numpy.ndarray'>
# [[237 200 124 124]]
# <class 'numpy.ndarray'>
# [[238 200 121 121]]
# <class 'numpy.ndarray'>
# [[240 201 119 119]]
# <class 'numpy.ndarray'>
# [[240 201 119 119]]
# <class 'numpy.ndarray'>
# [[240 202 118 118]]
# <class 'numpy.ndarray'>
# [[238 202 118 118]]
# <class 'numpy.ndarray'>
# [[238 201 121 121]]
# <class 'numpy.ndarray'>
# [[240 202 117 117]]
# <class 'numpy.ndarray'>
# [[239 202 117 117]]
# <class 'numpy.ndarray'>
# [[240 203 117 117]]
# <class 'numpy.ndarray'>
# [[239 201 118 118]]
# <class 'numpy.ndarray'>
# [[240 202 114 114]]
# <class 'numpy.ndarray'>
# [[238 201 115 115]]
# <class 'numpy.ndarray'>
# [[235 198 120 120]]
# <class 'numpy.ndarray'>
# [[233 200 119 119]]
# <class 'numpy.ndarray'>
# [[233 200 118 118]]
# <class 'numpy.ndarray'>
# [[231 201 115 115]]
# <class 'numpy.ndarray'>
# [[228 201 115 115]]
# <class 'numpy.ndarray'>
# [[222 199 118 118]]
# <class 'numpy.ndarray'>
# [[221 201 115 115]]
# <class 'numpy.ndarray'>
# [[218 200 115 115]]
# <class 'numpy.ndarray'>
# [[212 198 121 121]]
# <class 'numpy.ndarray'>
# [[335 257  49  49]
#  [210 198 119 119]]
# <class 'numpy.ndarray'>
# [[206 198 116 116]]
# <class 'numpy.ndarray'>
# [[206 199 114 114]]
# <class 'numpy.ndarray'>
# [[201 199 115 115]]
# <class 'numpy.ndarray'>
# [[197 198 115 115]]
# <class 'numpy.ndarray'>
# [[194 200 112 112]]
# <class 'numpy.ndarray'>
# [[192 201 110 110]]
# <class 'numpy.ndarray'>
# [[187 199 113 113]]
# <class 'numpy.ndarray'>
# [[184 197 115 115]]
# <class 'numpy.ndarray'>
# [[181 197 115 115]]
# <class 'numpy.ndarray'>
# [[177 198 114 114]]
# <class 'numpy.ndarray'>
# [[175 198 114 114]]
# <class 'numpy.ndarray'>
# [[174 199 112 112]]
# <class 'numpy.ndarray'>
# [[169 197 114 114]]
# <class 'numpy.ndarray'>
# [[167 197 113 113]]
# <class 'numpy.ndarray'>
# [[169 198 107 107]]
# <class 'numpy.ndarray'>
# [[168 196 110 110]]
# <class 'numpy.ndarray'>
# [[170 195 110 110]]
# <class 'numpy.ndarray'>
# [[169 195 111 111]]
# <class 'numpy.ndarray'>
# [[168 194 112 112]]
# <class 'numpy.ndarray'>
# [[171 195 112 112]]
# <class 'numpy.ndarray'>
# [[176 196 106 106]]
# <class 'numpy.ndarray'>
# [[177 193 112 112]]
# <class 'numpy.ndarray'>
# [[184 190 115 115]]
# <class 'numpy.ndarray'>
# [[192 191 107 107]]
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[223 198 122 122]]
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[217 191 128 128]]
# <class 'numpy.ndarray'>
# [[219 195 119 119]]
# <class 'numpy.ndarray'>
# [[218 194 118 118]]
# <class 'numpy.ndarray'>
# [[215 195 114 114]]
# <class 'numpy.ndarray'>
# [[218 194 117 117]]
# <class 'numpy.ndarray'>
# [[216 194 118 118]]
# <class 'numpy.ndarray'>
# [[216 192 119 119]]
# <class 'numpy.ndarray'>
# [[219 194 115 115]]
# <class 'numpy.ndarray'>
# [[221 193 119 119]]
# <class 'numpy.ndarray'>
# [[222 194 120 120]]
# <class 'numpy.ndarray'>
# [[230 196 112 112]]
# <class 'numpy.ndarray'>
# [[227 193 120 120]]
# <class 'numpy.ndarray'>
# [[230 194 117 117]]
# <class 'numpy.ndarray'>
# [[234 197 112 112]]
# <class 'numpy.ndarray'>
# [[235 198 110 110]]
# <class 'numpy.ndarray'>
# [[235 197 111 111]]
# <class 'numpy.ndarray'>
# [[236 198 109 109]]
# <class 'numpy.ndarray'>
# [[238 198 109 109]]
# <class 'numpy.ndarray'>
# [[239 200 106 106]]
# <class 'numpy.ndarray'>
# [[240 198 107 107]]
# <class 'numpy.ndarray'>
# [[241 200 106 106]]
# <class 'numpy.ndarray'>
# [[243 202 104 104]]
# <class 'numpy.ndarray'>
# [[243 203 105 105]]
# <class 'numpy.ndarray'>
# [[244 203 106 106]]
# <class 'numpy.ndarray'>
# [[244 203 106 106]]
# <class 'numpy.ndarray'>
# [[244 203 107 107]]
# <class 'numpy.ndarray'>
# [[247 204 102 102]]
# <class 'numpy.ndarray'>
# [[248 205 101 101]]
# <class 'numpy.ndarray'>
# [[246 202 104 104]]
# <class 'numpy.ndarray'>
# [[248 202 101 101]]
# <class 'numpy.ndarray'>
# [[247 200 106 106]]
# <class 'numpy.ndarray'>
# [[250 200 103 103]]
# <class 'numpy.ndarray'>
# [[253 200 102 102]]
# <class 'numpy.ndarray'>
# [[256 201 103 103]]
# <class 'numpy.ndarray'>
# [[259 201 103 103]]
# <class 'numpy.ndarray'>
# [[263 202 103 103]]
# <class 'numpy.ndarray'>
# [[264 203 104 104]]
# <class 'numpy.ndarray'>
# [[268 203 103 103]]
# <class 'numpy.ndarray'>
# [[268 203 105 105]]
# <class 'numpy.ndarray'>
# [[271 204 103 103]]
# <class 'numpy.ndarray'>
# [[271 204 105 105]]
# <class 'numpy.ndarray'>
# [[273 201 106 106]]
# <class 'numpy.ndarray'>
# [[274 202 104 104]]
# <class 'numpy.ndarray'>
# [[274 202 105 105]]
# <class 'numpy.ndarray'>
# [[274 202 104 104]]
# <class 'numpy.ndarray'>
# [[275 203 102 102]]
# <class 'numpy.ndarray'>
# [[275 203 101 101]]
# <class 'numpy.ndarray'>
# [[270 199 106 106]]
# <class 'numpy.ndarray'>
# [[267 199 104 104]]
# <class 'numpy.ndarray'>
# [[263 200 103 103]]
# <class 'numpy.ndarray'>
# [[258 200 101 101]]
# <class 'numpy.ndarray'>
# [[252 198 101 101]]
# <class 'numpy.ndarray'>
# [[245 198 101 101]]
# <class 'numpy.ndarray'>
# [[237 198 101 101]]
# <class 'numpy.ndarray'>
# [[227 197 103 103]]
# <class 'numpy.ndarray'>
# [[215 197 103 103]]
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[194 195 104 104]]
# <class 'numpy.ndarray'>
# [[203 194 102 102]]
# <class 'numpy.ndarray'>
# [[210 192 106 106]]
# <class 'numpy.ndarray'>
# [[219 195 103 103]]
# <class 'numpy.ndarray'>
# [[227 194 102 102]]
# <class 'numpy.ndarray'>
# [[232 194 104 104]]
# <class 'numpy.ndarray'>
# [[240 196 100 100]]
# <class 'numpy.ndarray'>
# [[246 195 101 101]]
# <class 'numpy.ndarray'>
# [[247 194 104 104]]
# <class 'numpy.ndarray'>
# [[250 193 102 102]]
# <class 'numpy.ndarray'>
# [[251 193 106 106]]
# <class 'numpy.ndarray'>
# [[254 194 102 102]]
# <class 'numpy.ndarray'>
# [[255 194 102 102]]
# <class 'numpy.ndarray'>
# [[255 194 101 101]]
# <class 'numpy.ndarray'>
# [[254 193 103 103]]
# <class 'numpy.ndarray'>
# [[253 194 103 103]]
# <class 'numpy.ndarray'>
# [[252 193 103 103]]
# <class 'numpy.ndarray'>
# [[248 192 104 104]]
# <class 'numpy.ndarray'>
# [[248 193  96  96]]
# <class 'numpy.ndarray'>
# [[242 193 101 101]]
# <class 'numpy.ndarray'>
# [[240 192 101 101]]
# <class 'numpy.ndarray'>
# [[233 189 106 106]]
# <class 'numpy.ndarray'>
# [[230 189 106 106]]
# <class 'numpy.ndarray'>
# [[226 189 108 108]]
# <class 'numpy.ndarray'>
# [[225 188 105 105]]
# <class 'numpy.ndarray'>
# [[221 190 107 107]]
# <class 'numpy.ndarray'>
# [[221 188 105 105]]
# <class 'numpy.ndarray'>
# [[218 189 104 104]]
# <class 'numpy.ndarray'>
# [[217 187 106 106]]
# <class 'numpy.ndarray'>
# [[213 189 107 107]]
# <class 'numpy.ndarray'>
# [[216 190 103 103]]
# <class 'numpy.ndarray'>
# [[216 190 102 102]]
# <class 'numpy.ndarray'>
# [[217 190  99  99]]
# <class 'numpy.ndarray'>
# [[215 188 104 104]]
# <class 'numpy.ndarray'>
# [[215 189 103 103]]
# <class 'numpy.ndarray'>
# [[217 188 104 104]]
# <class 'numpy.ndarray'>
# [[218 189 101 101]]
# <class 'numpy.ndarray'>
# [[221 191  97  97]]
# <class 'numpy.ndarray'>
# [[220 190  99  99]]
# <class 'numpy.ndarray'>
# [[222 189  98  98]]
# <class 'numpy.ndarray'>
# [[222 188 101 101]]
# <class 'numpy.ndarray'>
# [[224 189  98  98]]
# <class 'numpy.ndarray'>
# [[225 189  97  97]]
# <class 'numpy.ndarray'>
# [[225 189  98  98]]
# <class 'numpy.ndarray'>
# [[229 191  92  92]]
# <class 'numpy.ndarray'>
# [[229 191  94  94]]
# <class 'numpy.ndarray'>
# [[228 189  97  97]]
# <class 'numpy.ndarray'>
# [[229 189  98  98]]
# <class 'numpy.ndarray'>
# [[230 189  97  97]]
# <class 'numpy.ndarray'>
# [[229 188 101 101]]
# <class 'numpy.ndarray'>
# [[231 189  98  98]]
# <class 'numpy.ndarray'>
# [[232 189  96  96]]
# <class 'numpy.ndarray'>
# [[234 189  96  96]]
# <class 'numpy.ndarray'>
# [[235 189  93  93]]
# <class 'numpy.ndarray'>
# [[236 189  93  93]]
# <class 'numpy.ndarray'>
# [[232 186 103 103]]
# <class 'numpy.ndarray'>
# [[229 187 109 109]]
# <class 'numpy.ndarray'>
# [[230 189 106 106]]
# <class 'numpy.ndarray'>
# [[231 189 107 107]]
# <class 'numpy.ndarray'>
# [[230 189 109 109]]
# <class 'numpy.ndarray'>
# [[231 189 105 105]]
# <class 'numpy.ndarray'>
# [[231 189 107 107]]
# <class 'numpy.ndarray'>
# [[232 189 104 104]]
# <class 'numpy.ndarray'>
# [[234 189 102 102]]
# <class 'numpy.ndarray'>
# [[232 189 104 104]]
# <class 'numpy.ndarray'>
# [[233 190 104 104]]
# <class 'numpy.ndarray'>
# [[233 189 104 104]]
# <class 'numpy.ndarray'>
# [[231 191 107 107]]
# <class 'numpy.ndarray'>
# [[228 190 111 111]]
# <class 'numpy.ndarray'>
# [[232 190 105 105]]
# <class 'numpy.ndarray'>
# [[232 192 107 107]]
# <class 'numpy.ndarray'>
# [[233 192 102 102]]
# <class 'numpy.ndarray'>
# [[232 191 104 104]]
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[235 195  97  97]]
# <class 'numpy.ndarray'>
# [[236 194  98  98]]
# <class 'numpy.ndarray'>
# [[236 194  99  99]]
# <class 'numpy.ndarray'>
# [[235 194 100 100]]
# <class 'numpy.ndarray'>
# [[235 194 100 100]]
# <class 'numpy.ndarray'>
# [[235 194  98  98]]
# <class 'numpy.ndarray'>
# [[235 194 100 100]]
# <class 'numpy.ndarray'>
# [[235 194 100 100]]
# <class 'numpy.ndarray'>
# [[235 194 100 100]]
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[234 194 101 101]]
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[235 195  98  98]]
# <class 'numpy.ndarray'>
# [[234 194  99  99]]
# <class 'numpy.ndarray'>
# [[235 194  99  99]]
# <class 'numpy.ndarray'>
# [[237 198  89  89]]
# <class 'numpy.ndarray'>
# [[238 197  89  89]]
# <class 'numpy.ndarray'>
# [[235 194  98  98]]
# <class 'numpy.ndarray'>
# [[235 194 101 101]]
# <class 'numpy.ndarray'>
# [[236 195  97  97]]
# <class 'numpy.ndarray'>
# [[236 195  97  97]]
# <class 'numpy.ndarray'>
# [[235 194  99  99]]
# <class 'numpy.ndarray'>
# [[235 195  97  97]]
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[235 195  97  97]]
# <class 'numpy.ndarray'>
# [[234 194 100 100]]
# <class 'numpy.ndarray'>
# [[236 195  97  97]]
# <class 'numpy.ndarray'>
# [[236 196  97  97]]
# <class 'numpy.ndarray'>
# [[237 194  97  97]]
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[238 194  89  89]]
# <class 'numpy.ndarray'>
# [[233 190 102 102]]
# <class 'numpy.ndarray'>
# [[234 188 102 102]]
# <class 'numpy.ndarray'>
# [[237 187 101 101]]
# <class 'numpy.ndarray'>
# [[239 188  96  96]]
# <class 'numpy.ndarray'>
# [[239 190  94  94]]
# <class 'numpy.ndarray'>
# [[242 190  89  89]]
# <class 'numpy.ndarray'>
# [[236 186 104 104]]
# <class 'numpy.ndarray'>
# [[238 185  99  99]]
# <class 'numpy.ndarray'>
# [[239 186  96  96]]
# <class 'numpy.ndarray'>
# [[241 186  95  95]]
# <class 'numpy.ndarray'>
# [[240 185  96  96]]
# <class 'numpy.ndarray'>
# [[243 186  92  92]]
# <class 'numpy.ndarray'>
# [[242 186  92  92]]
# <class 'numpy.ndarray'>
# [[242 186  92  92]]
# <class 'numpy.ndarray'>
# [[243 186  91  91]]
# <class 'numpy.ndarray'>
# [[244 186  90  90]]
# <class 'numpy.ndarray'>
# [[244 187  90  90]]
# <class 'numpy.ndarray'>
# [[244 187  91  91]]
# <class 'numpy.ndarray'>
# [[245 186  89  89]]
# <class 'numpy.ndarray'>
# [[244 185  93  93]]
# <class 'numpy.ndarray'>
# [[246 186  89  89]]
# <class 'numpy.ndarray'>
# [[245 186  90  90]]
# <class 'numpy.ndarray'>
# [[246 187  89  89]]
# <class 'numpy.ndarray'>
# [[247 187  88  88]]
# <class 'numpy.ndarray'>
# [[247 186  88  88]]
# <class 'numpy.ndarray'>
# [[247 187  87  87]]
# <class 'numpy.ndarray'>
# [[249 188  84  84]]
# <class 'numpy.ndarray'>
# [[248 188  84  84]]
# <class 'numpy.ndarray'>
# [[247 187  85  85]]
# <class 'numpy.ndarray'>
# [[247 187  84  84]]
# <class 'numpy.ndarray'>
# [[247 187  85  85]]
# <class 'numpy.ndarray'>
# [[246 186  87  87]]
# <class 'numpy.ndarray'>
# [[245 186  87  87]]
# <class 'numpy.ndarray'>
# [[245 187  86  86]]
# <class 'numpy.ndarray'>
# [[244 187  88  88]]
# <class 'numpy.ndarray'>
# [[243 186  90  90]]
# <class 'numpy.ndarray'>
# [[244 187  89  89]]
# <class 'numpy.ndarray'>
# [[242 187  90  90]]
# <class 'numpy.ndarray'>
# [[244 186  86  86]]
# <class 'numpy.ndarray'>
# [[245 185  85  85]]
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[235 186 102 102]]
# <class 'numpy.ndarray'>
# [[235 186 102 102]]
# <class 'numpy.ndarray'>
# [[238 188  99  99]]
# <class 'numpy.ndarray'>
# [[231 188 116 116]]
# <class 'numpy.ndarray'>
# [[234 188 108 108]]
# <class 'numpy.ndarray'>
# [[236 189 102 102]]
# <class 'numpy.ndarray'>
# [[235 189 105 105]]
# <class 'numpy.ndarray'>
# [[236 189 103 103]]
# <class 'numpy.ndarray'>
# [[237 189 101 101]]
# <class 'numpy.ndarray'>
# [[237 189 100 100]]
# <class 'numpy.ndarray'>
# [[236 189 102 102]]
# <class 'numpy.ndarray'>
# [[237 190 100 100]]
# <class 'numpy.ndarray'>
# [[236 189 102 102]]
# <class 'numpy.ndarray'>
# [[237 189 102 102]]
# <class 'numpy.ndarray'>
# [[237 189 102 102]]
# <class 'numpy.ndarray'>
# [[236 189 102 102]]
# <class 'numpy.ndarray'>
# [[236 189 101 101]]
# <class 'numpy.ndarray'>
# [[236 189 101 101]]
# <class 'numpy.ndarray'>
# [[237 189 101 101]]
# <class 'numpy.ndarray'>
# [[231 187 109 109]]
# <class 'numpy.ndarray'>
# [[233 187 107 107]]
# <class 'numpy.ndarray'>
# [[231 186 109 109]]
# <class 'numpy.ndarray'>
# [[226 187 116 116]]
# <class 'numpy.ndarray'>
# [[235 188 104 104]]
# <class 'numpy.ndarray'>
# [[233 187 106 106]]
# <class 'numpy.ndarray'>
# [[234 189 102 102]]
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'tuple'>
# ()
# <class 'numpy.ndarray'>
# [[236 185 102 102]]
# <class 'numpy.ndarray'>
# [[237 186 101 101]]
# <class 'numpy.ndarray'>
# [[242 189  90  90]]
# <class 'numpy.ndarray'>
# [[243 190  88  88]]
# <class 'numpy.ndarray'>
# [[243 190  89  89]]
# <class 'numpy.ndarray'>
# [[242 188  91  91]]
# <class 'numpy.ndarray'>
# [[244 189  88  88]]
# <class 'numpy.ndarray'>
# [[243 188  90  90]]
# <class 'numpy.ndarray'>
# [[243 189  91  91]]
# <class 'numpy.ndarray'>
# [[241 188  96  96]]
# <class 'numpy.ndarray'>
# [[239 188  98  98]]
# <class 'numpy.ndarray'>
# [[239 187  97  97]]
# <class 'numpy.ndarray'>
# [[240 188  96  96]]
# <class 'numpy.ndarray'>
# [[239 187  96  96]]
# <class 'numpy.ndarray'>
# [[240 188  95  95]]
# <class 'numpy.ndarray'>
# [[238 187  99  99]]
# <class 'numpy.ndarray'>
# [[237 186 101 101]]
# <class 'numpy.ndarray'>
# [[240 189  95  95]]
# <class 'numpy.ndarray'>
# [[237 187  99  99]]
# <class 'numpy.ndarray'>
# [[238 187 100 100]]
# <class 'numpy.ndarray'>
# [[237 186 102 102]]
# <class 'numpy.ndarray'>
# [[237 186 102 102]]
# <class 'numpy.ndarray'>
# [[237 186 104 104]]
# <class 'numpy.ndarray'>
# [[235 187 108 108]]
# <class 'numpy.ndarray'>
# [[235 187 109 109]]
# <class 'numpy.ndarray'>
# [[237 190 103 103]]
# <class 'numpy.ndarray'>
# [[236 189 106 106]]
# <class 'numpy.ndarray'>
# [[235 191 106 106]]
# <class 'numpy.ndarray'>
# [[235 193 105 105]]
# <class 'numpy.ndarray'>
# [[235 194 103 103]]
# <class 'numpy.ndarray'>
# [[236 196 102 102]]
# <class 'numpy.ndarray'>
# [[235 196 101 101]]
# <class 'numpy.ndarray'>
# [[234 194 104 104]]
# <class 'numpy.ndarray'>
# [[233 194 105 105]]
# <class 'numpy.ndarray'>
# [[235 195 103 103]]
# <class 'numpy.ndarray'>
# [[234 195 103 103]]
# <class 'numpy.ndarray'>
# [[235 194 103 103]]
# <class 'numpy.ndarray'>
# [[234 194 104 104]]
# <class 'numpy.ndarray'>
# [[234 194 104 104]]
# <class 'numpy.ndarray'>
# [[235 194 102 102]]
# <class 'numpy.ndarray'>
# [[235 194 103 103]]
# <class 'numpy.ndarray'>
# [[234 195 105 105]]
# <class 'numpy.ndarray'>
# [[236 197  99  99]]
# <class 'numpy.ndarray'>
# [[230 194 108 108]]
# <class 'numpy.ndarray'>
# [[232 195 106 106]]
# <class 'numpy.ndarray'>
# [[232 196 106 106]]
# <class 'numpy.ndarray'>
# [[234 198 101 101]]
# <class 'numpy.ndarray'>
# [[234 197 102 102]]
# <class 'numpy.ndarray'>
# [[234 199 102 102]]
# <class 'numpy.ndarray'>
# [[234 198 103 103]]
# <class 'numpy.ndarray'>
# [[233 199 106 106]]
# <class 'numpy.ndarray'>
# [[231 196 110 110]]
# <class 'numpy.ndarray'>
# [[232 197 109 109]]
# <class 'numpy.ndarray'>
# [[233 198 109 109]]
# <class 'numpy.ndarray'>
# [[232 198 109 109]]
# <class 'numpy.ndarray'>
# [[232 199 109 109]]
# <class 'numpy.ndarray'>
# [[233 200 108 108]]
# <class 'numpy.ndarray'>
# [[233 200 108 108]]
# <class 'numpy.ndarray'>
# [[234 200 106 106]]
# <class 'numpy.ndarray'>
# [[233 200 109 109]]
# <class 'numpy.ndarray'>
# [[232 199 111 111]]
# <class 'numpy.ndarray'>
# [[234 201 107 107]]
# <class 'numpy.ndarray'>
# [[234 201 107 107]]
# <class 'numpy.ndarray'>
# [[234 200 111 111]]
# <class 'numpy.ndarray'>
# [[234 200 110 110]]
# <class 'numpy.ndarray'>
# [[233 201 110 110]]
# <class 'numpy.ndarray'>
# [[233 201 112 112]]
# <class 'numpy.ndarray'>
# [[235 203 108 108]]
# <class 'numpy.ndarray'>
# [[233 202 112 112]]
# <class 'numpy.ndarray'>
# [[234 203 111 111]]
# <class 'numpy.ndarray'>
# [[234 203 112 112]]
# <class 'numpy.ndarray'>
# [[234 203 112 112]]
# <class 'numpy.ndarray'>
# [[234 204 112 112]]
# <class 'numpy.ndarray'>
# [[233 205 114 114]]
# <class 'numpy.ndarray'>
# [[234 205 113 113]]
# <class 'numpy.ndarray'>
# [[234 205 113 113]]
# <class 'numpy.ndarray'>
# [[235 205 113 113]]
# <class 'numpy.ndarray'>
# [[234 206 112 112]]
# <class 'numpy.ndarray'>
# [[234 206 112 112]]
# <class 'numpy.ndarray'>
# [[235 207 111 111]]
# <class 'numpy.ndarray'>
# [[235 207 112 112]]
# <class 'numpy.ndarray'>
# [[236 206 113 113]]
# <class 'numpy.ndarray'>
# [[236 207 112 112]]
# <class 'numpy.ndarray'>
# [[236 207 111 111]]
# <class 'numpy.ndarray'>
# [[236 207 112 112]]
# <class 'numpy.ndarray'>
# [[236 207 112 112]]
# <class 'numpy.ndarray'>
# [[235 206 116 116]]
# <class 'numpy.ndarray'>
# [[237 208 112 112]]
# <class 'numpy.ndarray'>
# [[235 206 117 117]]
# <class 'numpy.ndarray'>
# [[236 207 112 112]]
# <class 'numpy.ndarray'>
# [[236 206 116 116]]
# <class 'numpy.ndarray'>
# [[239 209 111 111]]
# <class 'numpy.ndarray'>
# [[240 210 111 111]]
# <class 'numpy.ndarray'>
# [[238 207 116 116]]
# <class 'numpy.ndarray'>
# [[241 208 112 112]]
# <class 'numpy.ndarray'>
# [[240 207 114 114]]
# <class 'numpy.ndarray'>
# [[241 207 112 112]]

# %% [markdown]
# ### tutup kamera dan semua jendela

# %%
camera.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Kesimpulan
#
# Face tracking menggunakan Cascade Classifier dari OpenCV itu salah satu cara untuk membuat komputer mendeteksi wajah secara realtime. Walau hasilnya masih banyak kekurangannya, tetapi ini adalah salah satu metode pembelajaran yang mudah untuk mengenali wajah secara realtime. Dengan pehamanan dasar ini bisa dikembangkan lagi untuk membuat sistem keamanan ataupun robot yang bergerak jika mendeteksi wajah.
